# %% [markdown]
# ### Import Libraries

# %%
import pyodbc
import pandas as pd
import os
import time
import numpy as np

# %%
# root directory of the assessment
root_dir = os.getcwd()     

# this is path to the dataset
dataset = os.path.join(root_dir, "dataset")

# load excel dataset
dsr_data = os.path.join(dataset, "DSR.xlsx")
farms_data = os.path.join(dataset, "farms.xlsx")
producers_data = os.path.join(dataset, "producers.xlsx")
varieties_data = os.path.join(dataset, "varieties.xlsx")
vessels_data = os.path.join(dataset, "vessels.xlsx")

# loop through all the drivers we have access to
for driver in pyodbc.drivers():
    print(driver)
# Out:
# SQL Server
# SQL Server Native Client 11.0
# ODBC Driver 17 for SQL Server
# SQL Server Native Client RDA 11.0

# %% [markdown]
# ### Connecting to the Databases

# %%
class ConnectDB(object):
    """
    This is a blueprint for codnnecting to the local databases
    """
    
    def __init__(self):
        self.server = "DESKTOP-E5PL80T\SQLEXPRESS"
        self.database = "Atom_Assessment_2021"
    
    def get_connection(self):
        """
        This method connects to the database
        :returns:
            cur, conn
        """

        try:
            # connect to the database
            conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server}; \
                   SERVER=' + self.server + '; \
                   DATABASE=' + self.database +';\
                   Trusted_Connection=yes;')
            cursor = conn.cursor()
            print("Connecion created")
        
        except Exception as e:
                
            print("Error: Could not get the cursor to the database")
            print(e)
        
        return conn, cursor

# %%
# start time
start_time = time.time()

# define db connect object
connect_db_object = ConnectDB()

# establish the connection 
conn, cursor = connect_db_object.get_connection()
print("Time to connect to the DB: ",round((time.time() - start_time)/60,5),"minutes")
# Out:
# Connecion created
# Time to connect to the DB:  0.00161 minutes

# %% [markdown]
# ### Display Table Names from the Server

# %%
# sql quecry for displaying all tables from the databases
cursor.execute("SELECT table_name FROM information_schema.tables;")

# fetch all tables
tables  = cursor.fetchall()

# iterate through the database and display all table names
for table_name in tables:
    print(table_name)
# Out:
# ('DSR', )
# ('Farms', )
# ('Producers', )
# ('Varieties', )
# ('Vessels', )

# %% [markdown]
# ### Load Excel Dataset

# %%
class DataPreprocessing(object):
    """
    This is a blueprint for loading dataset
    """
    def __init__(self):
        pass
    
    def get_excel_data(self, file_name):
        """
        This method loads excel dataset
        
        args:
            file_name: the name of the file
            excel_file: file to import into the sql database
            
        returns: 
            dataframe
        """
        pd.set_option("display.max_columns", None)
        df = pd.read_excel(open(file_name,'rb'))
        
        return df
    
#     def load_data_to_db(self, tb_name, conn, data):
#         """
#         This method loads excel data to the dabase
        
#         """
        
#         # data.to_sql('book_details', con = engine, if_exists = 'append', chunksize = 1000)
        
#         sql_insert = "INSERT INTO "
#         data.to_sql(tb_name , con = conn, if_exists = "append")
#         print("Successfully imported {} data into the database".format( data))
        
    def get_preprocessing(self, df):
        """
        This method prints the sum of null values and replace null values with 0 for easier processing.
        
        arg:
        --- df: this is an excel dataframe with null values
        
        returns:
        --- df: preprocesses excel dataframe 
        """
        
        # compute the sum of null values in the dataframe
        sum_of_null_values = df.isnull().sum()
            
        print("Sum of null values in the dataframe:")    
        print(sum_of_null_values)
        
        # replaced inf values with nan and it worked
        df.replace([np.inf, -np.inf], np.nan, inplace = True)
        
        # fill ann null values with zeros 
        df = df.fillna(0)
        
        return df

# %% [markdown]
# ### Load Detailed Season Report (DSR) Raw Dataset

# %%
# excel data object
excel_data_object = DataPreprocessing()

# load dsr dataframe 
dsr_df = excel_data_object.get_excel_data(dsr_data)

print("Time to load DSR data: ",round((time.time() - start_time)/60,5),"minutes")
# Out:
# Time to load DSR data:  1.84504 minutes

# %%
# initialize preprocessing object
preprocessing_object = DataPreprocessing()

# get DRS dataframe
dsr_df = preprocessing_object.get_preprocessing(dsr_df)

# visualize DSR raw dataset
dsr_df.head()
# Out:
# Sum of null values in the dataframe:
# Year                       0
# ProducerID                 0
# FarmID                     0
# Sales Week                 0
# Pallet ID                  0
# Sale ID                    0
# Barcode                    0
# Grade Code                 0
# Mark Code                  0
# VarietyID                  0
# Pack Code                  0
# Count Code                 2
# Exchange Rate              0
# Currency                   0
# QC                         0
# Sequence Number            0
# Production ID            209
# Run Number             96551
# Container No           55337
# VesselID                   0
# Port Of Discharge      42479
# Target Market              0
# Inventory Code           587
# Trader ID                  0
# Pallet Size                0
# From Barcode             211
# To Barcode                 0
# Invoice ID                 0
# Selected                 209
# No Cartons                 0
# Advance Price              0
# Producer Adjustment        0
# Advance Purchase          44
# Purchase Price           164
# Final Price                0
# Total                      0
# Debit Note                 0
# Credit Note                0
# Total Local Cost           0
# Total Export Cost          0
# Total Weight               0
# Pack Nett Weight         119
# Nett Weight              119
# Pack Gross Weight        415
# Gross Weight             415
# FOB                        0
# DIP                        0
# VAT                    14787
# Return To Grower           0
# dtype: int64
#    Year  ProducerID  FarmID  Sales Week  Pallet ID  Sale ID  \
# 0  2017      201100      45          24     201233     3124
# 1  2017      201100      45          25     207565    10375
# 2  2017      201100      45          25     100285    10375
# 3  2017      201100      45          25     181685     7374
# 4  2017      201100      45          26      66238     6697
#
#               Barcode Grade Code Mark Code  VarietyID Pack Code Count Code  \
# 0  960091600127485952          1       AMA         74      A15C         72
# 1  960091600127457024          1       AMA         74      A15C         64
# 2  960091600127485952          1       AMA         74      A15C         64
# 3  960091600127457024          1       AMA         74      A15C         64
# 4  960091600127469952          1       AMA        700      A15C        125
#
#    Exchange Rate Currency     QC  Sequence Number  Production ID Run Number  \
# 0      13.424682      USD  False                1          291.0          0
# 1      13.210000      USD  False                1          291.0          0
# 2      13.210000      USD  False                1          291.0          0
# 3      13.583237      USD  False                1          291.0          0
# 4      13.411510      USD  False                1          291.0          0
#
#   Container No  VesselID Port Of Discharge Target Market Inventory Code  \
# 0  CXRU1499008      6798             BDCGP            ME             WA
# 1  MWCU6671193      2276             SAJED            ME             WA
# 2  MWCU6671193      2276             SAJED            ME             WA
# 3  PONU4875876      2276             SAJED            ME             WA
# 4  PONU4883819      1337             SAJED            ME             WA
#
#   Trader ID  Pallet Size        From Barcode          To Barcode  Invoice ID  \
# 0  TRADER02          1.0  960091600127485952  960091600127485952        6100
# 1  TRADER02          1.0  960091600127457024  960091600127457024       11024
# 2  TRADER02          1.0  960091600127485952  960091600127485952       11024
# 3  TRADER02          1.0  960091600127457024  960091600127457024        2961
# 4  TRADER02          1.0  960091600127469952  960091600127469952       15710
#
#    Selected  No Cartons  Advance Price  Producer Adjustment  Advance Purchase  \
# 0       1.0          88              0                    0               0.0
# 1       1.0          91              0                    0               0.0
# 2       1.0          93              0                    0               0.0
# 3       1.0          89              0                    0               0.0
# 4       1.0          85              0                    0               0.0
#
#    Purchase Price  Final Price  Total  Debit Note  Credit Note  \
# 0             0.0         10.5  924.0         0.0          0.0
# 1             0.0         10.5  955.5         0.0          0.0
# 2             0.0         10.5  976.5         0.0          0.0
# 3             0.0         10.5  934.5         0.0          0.0
# 4             0.0          7.0  595.0         0.0          0.0
#
#    Total Local Cost  Total Export Cost  Total Weight  Pack Nett Weight  \
# 0        672.090194                0.0             0              16.0
# 1        701.575766                0.0             0              16.0
# 2        701.575766                0.0             0              16.0
# 3        754.994818                0.0             0              16.0
# 4        548.241212                0.0             0              16.0
#
#    Nett Weight  Pack Gross Weight  Gross Weight   FOB         DIP        VAT  \
# 0       1280.0              16.95        1356.0  10.5  139.324307 -55.907373
# 1       1280.0              16.95        1356.0  10.5  137.090203 -47.779393
# 2       1280.0              16.95        1356.0  10.5  137.090203  52.220607
# 3       1280.0              16.95        1356.0  10.5  141.074018 -40.300725
# 4       1280.0              16.95        1356.0   7.0   92.381472  73.753770
#
#    Return To Grower
# 0      10074.410440
# 1       9875.083022
# 2       9875.083022
# 3      10122.177720
# 4       6614.094181

# %% [markdown]
# ### Load Farms Raw Dataset

# %%
# start time
start_time = time.time()

# loads farms raw dataset
farms_df  = excel_data_object.get_excel_data(farms_data)

print("Time to loads farms data: ",round((time.time() - start_time)/60,5),"minutes")
# Out:
# Time to loads farms data:  0.00053 minutes

# %%
# get Farms dataframe
farms_df = preprocessing_object.get_preprocessing(farms_df)

# visualize Farms raw dataset
farms_df.head()
# Out:
# Sum of null values in the dataframe:
# ID           0
# Farm Name    0
# dtype: int64
#     ID Farm Name
# 0   45   Tel Dan
# 1   54   Urkish
# 2   62      Lehi
# 3   83      Shur
# 4  154   Havilah

# %% [markdown]
# ### Load Producers Raw Dataset

# %%
# start time
start_time = time.time()

# loads producers raw dataset
producers_df  =  excel_data_object.get_excel_data(producers_data)

print("Time to load producers: ",round((time.time() - start_time)/60,5),"minutes")
# Out:
# Time to load producers:  0.00042 minutes

# %%
# get Producers dataframe
producers_df = preprocessing_object.get_preprocessing(producers_df)

# visualize Producers raw dataset
producers_df.head()
# Out:
# Sum of null values in the dataframe:
# ID          0
# Producer    1
# dtype: int64
#        ID  Producer
# 0  201100  Alderaan
# 1  318820  Yavin IV
# 2  351986      Hoth
# 3  240822   Dagobah
# 4   11959    Bespin

# %% [markdown]
# ### Load Varieties Raw Dataset

# %%
# start time
start_time = time.time()

# loads varieties raw dataset
varieties_df  = excel_data_object.get_excel_data(varieties_data)

print("Time to connect to the DB: ",round((time.time() - start_time)/60,5),"minutes")
# Out:
# Time to connect to the DB:  0.0006 minutes

# %%
# get Varieties dataframe
varieties_df = preprocessing_object.get_preprocessing(varieties_df)

# visualize Varieties raw dataset
varieties_df.head()
# Out:
# Sum of null values in the dataframe:
# ID                 0
# Variety Group     16
# Variety Code       0
# Commodity Code     0
# dtype: int64
#     ID Variety Group Variety Code Commodity Code
# 0   45           AGN          AGN             OR
# 1  965           ALN          ALN             OR
# 2  937           ANL          ANL             OR
# 3  610           BAR          BAR             GR
# 4  686           BIN          ELL             SC

# %% [markdown]
# ### Load Vessels Raw Dataset

# %%
# start time
start_time = time.time()

# loads vessels raw dataset
vessels_df = excel_data_object.get_excel_data(vessels_data)

print("Time to connect to the DB: ",round((time.time() - start_time)/60,5),"minutes")
# Out:
# Time to connect to the DB:  0.00065 minutes

# %%
# get vessels dataframe
vessels_df = preprocessing_object.get_preprocessing(vessels_df)

# visualize vessels raw dataset
vessels_df.head()
# Out:
# Sum of null values in the dataframe:
# ID        0
# Vessel    1
# dtype: int64
#      ID          Vessel
# 0  4271  ADRIAN SCHULTE
# 1  1347       ALEXANDRA
# 2  2653        ALMAVIVA
# 3  4496       ALS Venus
# 4  6744        AMANDA D

# %% [markdown]
# ## 1. Import the Excel Data into a SQL Database

# %% [markdown]
# #### Import Detailed Season Report (DSR)

# %%
# interate through every row and insert into the database
for row in dsr_df.itertuples(index=False):
    cursor.execute("INSERT INTO db.DSR VALUES (?,?,?,?,?,?,?,?,?,?,\
                                               ?,?,?,?,?,?,?,?,?,?,\
                                               ?,?,?,?,?,?,?,?,?,?,\
                                               ?,?,?,?,?,?,?,?,?,?,\
                                               ?,?,?,?,?,?,?,?,?)",row)
    
# Save the changes
conn.commit()

# %% [markdown]
# #### Import Farms Dataset

# %%
# interate through every row and insert into the database
for row in farms_df.itertuples(index=False):
    cursor.execute("INSERT INTO db.Farms VALUES (?,?)",row)
    
# Save the changes
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-17-512dc16ff4c3> in <module>
#       1 # interate through every row and insert into the database
#       2 for row in farms_df.itertuples(index=False):
# ----> 3     cursor.execute("INSERT INTO db.Farms VALUES (?,?)",row)
#       4
#       5 # Save the changes
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__Farms__3214EC27A4B5F8D1'. Cannot insert duplicate key in object 'db.Farms'. The duplicate key value is (45). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)")

# %% [markdown]
# #### Import Producers Dataset

# %%
# interate through every row and insert into the database
for row in producers_df.itertuples(index=False):
    cursor.execute("INSERT INTO db.Producers VALUES (?,?)",row)
    
# Save the changes
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-19-4cfd1742f124> in <module>
#       1 # interate through every row and insert into the database
#       2 for row in producers_df.itertuples(index=False):
# ----> 3     cursor.execute("INSERT INTO db.Producers VALUES (?,?)",row)
#       4
#       5 # Save the changes
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__Producer__3214EC27AABCB035'. Cannot insert duplicate key in object 'db.Producers'. The duplicate key value is (201100). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)")

# %% [markdown]
# #### Import Varieties Dataset

# %%
# interate through every row and insert into the database
for row in varieties_df.itertuples(index=False):
    cursor.execute("INSERT INTO db.Varieties VALUES (?,?,?,?)",row)
    
# Save the changes
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-20-1fcac5ccf3fa> in <module>
#       1 # interate through every row and insert into the database
#       2 for row in varieties_df.itertuples(index=False):
# ----> 3     cursor.execute("INSERT INTO db.Varieties VALUES (?,?,?,?)",row)
#       4
#       5 # Save the changes
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__Varietie__3214EC27478C828C'. Cannot insert duplicate key in object 'db.Varieties'. The duplicate key value is (45). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)")

# %% [markdown]
# #### Import Vessels Dataset

# %%
# interate through every row and insert into the database
for row in vessels_df.itertuples(index=False):
    cursor.execute("INSERT INTO db.Vessels VALUES (?,?)",row)
    
# Save the changes
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-21-c2a4c600d399> in <module>
#       1 # interate through every row and insert into the database
#       2 for row in vessels_df.itertuples(index=False):
# ----> 3     cursor.execute("INSERT INTO db.Vessels VALUES (?,?)",row)
#       4
#       5 # Save the changes
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violation of PRIMARY KEY constraint 'PK__Vessels__3214EC276E009335'. Cannot insert duplicate key in object 'db.Vessels'. The duplicate key value is (4271). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)")

# %%
class DatabaseData(object):
    """
    This is class blueprints that gets ethe data from the database and execute queries.
    """
    def __init__(self):
        self.conn = conn    
    
    def get_table_data(self, table_name):
        """
        This method retrieves records from the database
        
        arg:
        ---table_name: the table_name that we want to access
        
        return:
        --- table: table from fetched from the database
        """
        query = "SELECT * FROM {table}".format(table = table_name)

        table = pd.read_sql_query(query,self.conn)

        return table  
    
    def get_table_columns(self, table):
        """
        This method lists column names
        
        arg:
        --- table: this is a table
        
        returns:
        --- columns: lists of all columns
        """
        
        columns = table.columns.values.tolist()
        
        return columns

# %%
# initialiase table object
table_object = DatabaseData()

# get dsr data from the database
dsr_table = table_object.get_table_data("db.DSR")

# get the number of columns
dsr_columns = table_object.get_table_columns(dsr_table)
dsr_columns
# Out:
# ['ID',
#  'Year',
#  'ProducerID',
#  'FarmID',
#  'Sales Week',
#  'Pallet ID',
#  'Sale ID',
#  'Barcode',
#  'Grade Code',
#  'Mark Code',
#  'VarietyID',
#  'Pack Code',
#  'Count Code',
#  'Exchange Rate',
#  'Currency',
#  'QC',
#  'Sequence Number',
#  'Production ID',
#  'Run Number',
#  'Container No',
#  'VesselID',
#  'Port Of Discharge',
#  'Target Market',
#  'Inventory Code',
#  'Trader ID',
#  'Pallet Size',
#  'From Barcode',
#  'To Barcode',
#  'Invoice ID',
#  'Selected',
#  'No Cartons',
#  'Advance Price',
#  'Producer Adjustment',
#  'Advance Purchase',
#  'Purchase Price',
#  'Final Price',
#  'Total',
#  'Debit Note',
#  'Credit Note',
#  'Total Local Cost',
#  'Total Export Cost',
#  'Total Weight',
#  'Pack Nett Weight',
#  'Nett Weight',
#  'Pack Gross Weight',
#  'Gross Weight',
#  'FOB',
#  'DIP',
#  'VAT',
#  'Return To Grower']

# %%
dsr_table
# Out:
#             ID  Year  ProducerID  FarmID  Sales Week  Pallet ID  Sale ID  \
# 0            1  2017      201100      45          24     201233     3124
# 1            2  2017      201100      45          25     207565    10375
# 2            3  2017      201100      45          25     100285    10375
# 3            4  2017      201100      45          25     181685     7374
# 4            5  2017      201100      45          26      66238     6697
# ...        ...   ...         ...     ...         ...        ...      ...
# 464809  464810  2016      231480    6453          48      77456     4085
# 464810  464811  2016      231480    6453          48     221143     4085
# 464811  464812  2016      231480    6453          52      67993     3846
# 464812  464813  2016      231480    6453          52      61374     3846
# 464813  464814  2016      231480    6453          52     161980     3846
#
#                    Barcode Grade Code Mark Code  VarietyID Pack Code  \
# 0       960091600127485952          1       AMA         74      A15C
# 1       960091600127457024          1       AMA         74      A15C
# 2       960091600127485952          1       AMA         74      A15C
# 3       960091600127457024          1       AMA         74      A15C
# 4       960091600127469952          1       AMA        700      A15C
# ...                    ...        ...       ...        ...       ...
# 464809  860091600127437056          1       BRI        441  3.5KG BA
# 464810  860091600127437056          1       BRI        441  3.5KG BA
# 464811  860091600127437056          1       BRI        441     3.5KG
# 464812  860091600127437056          1       BRI        441     LOOSE
# 464813  860091600127437056          1       BRI        441  3.5KG BA
#
#        Count Code  Exchange Rate Currency     QC  Sequence Number  \
# 0              72      13.424682      USD  False                1
# 1              64      13.210000      USD  False                1
# 2              64      13.210000      USD  False                1
# 3              64      13.583237      USD  False                1
# 4             125      13.411510      USD  False                1
# ...           ...            ...      ...    ...              ...
# 464809         72       1.000000      ZAR  False                1
# 464810         88       1.000000      ZAR  False                1
# 464811         88       1.000000      ZAR  False                1
# 464812        105       1.000000      ZAR  False                1
# 464813         72       1.000000      ZAR  False                1
#
#         Production ID Run Number Container No  VesselID Port Of Discharge  \
# 0               291.0          0  CXRU1499008      6798             BDCGP
# 1               291.0          0  MWCU6671193      2276             SAJED
# 2               291.0          0  MWCU6671193      2276             SAJED
# 3               291.0          0  PONU4875876      2276             SAJED
# 4               291.0          0  PONU4883819      1337             SAJED
# ...               ...        ...          ...       ...               ...
# 464809           26.0          0            0       654                 0
# 464810           26.0          0            0       654                 0
# 464811           26.0          0            0       654                 0
# 464812           26.0          0            0       654                 0
# 464813           26.0          0            0       654                 0
#
#        Target Market Inventory Code Trader ID  Pallet Size  \
# 0                 ME             WA  TRADER02       1.0000
# 1                 ME             WA  TRADER02       1.0000
# 2                 ME             WA  TRADER02       1.0000
# 3                 ME             WA  TRADER02       1.0000
# 4                 ME             WA  TRADER02       1.0000
# ...              ...            ...       ...          ...
# 464809            LO              .  TRADER01       0.0180
# 464810            LO              .  TRADER01       0.0148
# 464811            LO              .  TRADER01       0.0050
# 464812            LO              .  TRADER01       1.0000
# 464813            LO              .  TRADER01       0.1936
#
#               From Barcode          To Barcode  Invoice ID  Selected  \
# 0       960091600127485952  960091600127485952        6100       1.0
# 1       960091600127457024  960091600127457024       11024       1.0
# 2       960091600127485952  960091600127485952       11024       1.0
# 3       960091600127457024  960091600127457024        2961       1.0
# 4       960091600127469952  960091600127469952       15710       1.0
# ...                    ...                 ...         ...       ...
# 464809  860091600127437056  860091600127437056        3752       1.0
# 464810  860091600127437056  860091600127437056        3752       1.0
# 464811  860091600127437056  860091600127437056       11027       1.0
# 464812  860091600127437056  860091600127437056       11027       1.0
# 464813  860091600127437056  860091600127437056       11027       1.0
#
#         No Cartons  Advance Price  Producer Adjustment  Advance Purchase  \
# 0               88              0                    0               0.0
# 1               91              0                    0               0.0
# 2               93              0                    0               0.0
# 3               89              0                    0               0.0
# 4               85              0                    0               0.0
# ...            ...            ...                  ...               ...
# 464809          94              0                    0               0.0
# 464810          77              0                    0               0.0
# 464811        2788              0                    0               0.0
# 464812           1              0                    0               0.0
# 464813         980              0                    0               0.0
#
#         Purchase Price  Final Price         Total  Debit Note  Credit Note  \
# 0                  0.0    10.500000    924.000000         0.0          0.0
# 1                  0.0    10.500000    955.500000         0.0          0.0
# 2                  0.0    10.500000    976.500000         0.0          0.0
# 3                  0.0    10.500000    934.500000         0.0          0.0
# 4                  0.0     7.000000    595.000000         0.0          0.0
# ...                ...          ...           ...         ...          ...
# 464809             0.0   106.960866  10054.321421         0.0          0.0
# 464810             0.0   106.960866   8235.986696         0.0          0.0
# 464811             0.0    27.966811  77971.470206         0.0          0.0
# 464812             0.0  3557.106140   3557.106140         0.0          0.0
# 464813             0.0    28.309026  27742.845300         0.0          0.0
#
#         Total Local Cost  Total Export Cost  Total Weight  Pack Nett Weight  \
# 0             672.090194           0.000000             0              16.0
# 1             701.575766           0.000000             0              16.0
# 2             701.575766           0.000000             0              16.0
# 3             754.994818           0.000000             0              16.0
# 4             548.241212           0.000000             0              16.0
# ...                  ...                ...           ...               ...
# 464809          0.000000         290.481594             0               3.5
# 464810          0.000000         238.840421             0               3.5
# 464811          0.000000           2.512356             0               3.5
# 464812          0.000000         502.471206             0             370.0
# 464813          0.000000          97.278425             0               3.5
#
#         Nett Weight  Pack Gross Weight  Gross Weight          FOB  \
# 0            1280.0              16.95        1356.0    10.500000
# 1            1280.0              16.95        1356.0    10.500000
# 2            1280.0              16.95        1356.0    10.500000
# 3            1280.0              16.95        1356.0    10.500000
# 4            1280.0              16.95        1356.0     7.000000
# ...             ...                ...           ...          ...
# 464809        315.0               3.70         333.0   103.733293
# 464810        259.0               3.70         273.8   103.733293
# 464811       9744.0               3.50        9744.0    27.965909
# 464812        370.0             370.00         370.0  3054.634934
# 464813       3388.0               3.70        3581.6    28.208532
#
#                 DIP         VAT  Return To Grower
# 0        139.324307  -55.907373      10074.410440
# 1        137.090203  -47.779393       9875.083022
# 2        137.090203   52.220607       9875.083022
# 3        141.074018  -40.300725      10122.177720
# 4         92.381472   73.753770       6614.094181
# ...             ...         ...               ...
# 464809   103.733293  120.000000       8869.196544
# 464810   103.733293  142.000000       7292.450492
# 464811    27.965909  106.000000      73964.236074
# 464812  3054.634934 -101.000000       2901.903188
# 464813    28.208532   -5.000000      25940.565636
#
# [464814 rows x 50 columns]

# %% [markdown]
# ## 2. Produce an overview of the exporter's business.

# %% [markdown]
# #### 2.1 How many producers supplies fruit to this exporter.
# Assuming that each producer has a unique ID

# %%
table_name = "db.DSR"
query = """SELECT COUNT (DISTINCT ProducerID) FROM {table}""".format(table = table_name)
cursor.execute(query)
data = cursor.fetchall()
print("No of producers: {}".format(data))
# Out:
# No of producers: [(56, )]

# %% [markdown]
# #### 2.2 How many different varieties of fruit are being exported?
# Assuming each fruit exported has a unique ID e.g. Banana 11, Apple 12 etc

# %%
table_name =  "db.DSR"
query = """SELECT COUNT (DISTINCT VarietyID) FROM {table}""".format(table = table_name)
cursor.execute(query)
data = cursor.fetchall()
print("No of different varieties of fruit: {}".format(data))
# Out:
# No of different varieties of fruit: [(94, )]

# %% [markdown]
# #### 2.3 How many tons per variety are being supplied to the exporter?

# %% [markdown]
# #### 2.4 What is the average return are growers getting per standard carton?

# %% [markdown]
# #### 2.5 What are the most prominent Target Markets that fruit are exported to?

# %% [markdown]
# ## 3. Provide an overview of the producer named Corellia's.

# %% [markdown]
# #### 3.1
